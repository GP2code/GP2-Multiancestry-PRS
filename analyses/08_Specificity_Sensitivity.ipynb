# %% [markdown]
# # Estimate Specificity and Sensitivity
# - **Project:** Multi-ancestry PRS
# - **Version:** Python/3.9
# - **Status:** COMPLETE
# - **Last Updated:** 16-NOV-2023
#
# ## Notebook Overview
# - Specificity and Sensitivity

# %%
## Load packages
module load python
module load R

# %%
###################################### AAC ######################################

cd ${WORK_DIR}/AAC

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AAC/AAC_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat


library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AAC/AAC_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AAC/AAC_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AAC/AAC_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
###################################### AFR ######################################

cd ${WORK_DIR}/AFR

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AFR/AFR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AFR/AFR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AFR/AFR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AFR/AFR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
  ###################################### AJ ######################################

cd ${WORK_DIR}/AJ

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AJ/AJ_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat


library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AJ/AJ_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AJ/AJ_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat


library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AJ/AJ_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
###################################### AMR ######################################

cd ${WORK_DIR}/AMR

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AMR/AMR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AMR/AMR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat


library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AMR/AMR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/AMR/AMR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
###################################### CAS ######################################

cd ${WORK_DIR}/CAS

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/CAS/CAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/CAS/CAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/CAS/CAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/CAS/CAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
###################################### EAS ######################################

cd ${WORK_DIR}/EAS

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EAS/EAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EAS/EAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EAS/EAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat


library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EAS/EAS_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

# %%
###################################### EUR ######################################

cd ${WORK_DIR}/EUR

### RISK
R
library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_AFRICAN.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EUR/EUR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EUROPEANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EUR/EUR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_LATINO.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EUR/EUR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat

library(data.table)
library(caret)
temp_data <- read.table("PRS_score_release_EASTASIANS.profile", header = T)
temp_covs <- read.table("{GP2_release5}/raw_genotypes/EUR/EUR_release5_maf_hwe_pca.eigenvec", header = F, sep="\t")
colnames(temp_covs) <- c("FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10")
temp_covs_2 <- read.table("./covariates.txt", header = T, sep="\t")
colnames(temp_covs_2)[2] ="IID"
covs <- merge(temp_covs, temp_covs_2, by = "IID")
data <- merge(temp_data, covs, by = "IID")
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)
dat$sex_for_qc[dat$sex_for_qc =="Male"] <- 1
dat$sex_for_qc[dat$sex_for_qc =="Female"] <- 2
dat$sex_for_qc <- as.numeric(dat$sex_for_qc)
meanControls <- mean(dat$SCORE[dat$CASE == 0])
sdControls <- sd(dat$SCORE[dat$CASE == 0])
dat$zSCORE <- (dat$SCORE - meanControls)/sdControls
grsTests <- glm(CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10, family="binomial", data = dat)
summary(grsTests)
dat$probDisease <- predict(grsTests, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")
confMat <- confusionMatrix(data = as.factor(dat$predicted), reference = as.factor(dat$reported), positive = "DISEASE")
confMat
